# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train_labels.txt
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6459.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7450.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4465.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6846.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7469.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4291.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1858.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9829.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3338.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4086.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5623.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5775.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8151.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3178.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6126.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5643.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5516.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3253.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5562.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9738.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1860.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1252.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5896.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5645.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4900.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3008.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4951.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1582.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1973.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8310.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8256.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5588.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2325.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9026.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2438.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3148.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6167.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7053.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6379.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7181.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5177.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1039.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7551.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8756.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2414.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3079.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6207.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8555.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7886.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6519.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1531.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6228.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1620.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3162.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7230.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4075.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5128.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7034.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7411.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2735.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9636.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3760.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6227.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3499.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3722.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2357.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6796.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5618.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2652.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7023.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4549.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9128.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3360.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8013.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3857.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5248.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8863.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4817.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2939.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2443.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6757.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2164.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5577.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2682.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4510.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8325.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9124.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1320.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4783.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1879.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6234.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1019.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4571.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8898.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1704.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7862.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8588.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4240.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7863.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9557.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2565.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5061.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7055.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6067.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1811.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1211.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4517.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7457.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2152.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1850.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5503.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4869.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3618.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9179.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1904.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4700.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3147.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8467.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7383.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6347.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2540.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9558.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6927.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9118.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2635.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2572.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3018.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3885.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4912.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1504.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2665.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3665.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2376.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1092.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1445.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8157.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5582.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8781.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7258.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2529.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5885.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7734.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5094.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4883.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3428.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2273.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5969.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4653.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4501.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8359.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5022.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3751.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2161.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4106.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2942.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9312.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8697.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7385.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2167.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8397.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8860.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1608.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8640.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3308.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4859.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3594.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6713.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9250.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6907.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4600.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1652.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5913.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1564.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9434.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1394.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1956.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6417.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6838.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5923.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5247.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8580.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9561.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2187.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9092.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2891.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9377.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2296.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4738.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7094.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1881.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3606.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3878.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3160.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2013.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2045.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8664.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2536.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5986.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7112.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9541.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4537.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9125.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5974.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7900.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1870.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9289.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1311.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8001.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3040.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8252.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3601.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2846.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1610.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3207.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5870.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3783.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6991.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6711.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5410.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8955.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9063.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2274.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7489.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7027.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4415.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6958.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9119.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3505.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8473.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9673.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1691.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8201.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7044.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5529.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1101.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9697.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7476.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8479.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9247.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9825.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1344.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9050.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1544.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5395.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5816.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4855.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4397.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1461.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4457.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1665.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4207.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7510.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5514.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2524.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2880.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4767.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8183.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7058.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5350.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8769.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5086.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4532.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8579.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2716.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8249.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9274.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2563.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3638.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8621.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2086.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8892.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1448.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9757.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3500.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2150.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5683.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3734.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7742.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5032.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2271.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5149.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5467.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6605.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3894.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4770.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6253.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9358.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6652.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4566.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8941.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6064.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9745.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4385.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3748.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2401.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2581.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5296.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8651.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7409.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3217.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4515.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7534.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5528.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3517.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5769.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2988.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1613.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1240.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6439.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7074.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6318.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4293.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1078.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6624.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9166.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4024.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9110.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7859.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4668.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8072.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5070.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2496.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5765.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5095.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2514.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4003.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8910.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8167.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6723.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9080.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1776.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2215.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8273.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4061.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3860.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5131.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3415.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2410.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4593.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1115.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/4393.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1890.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7659.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1788.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9596.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7453.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8355.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6909.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3761.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3768.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8232.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2909.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6072.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9583.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8527.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7563.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8932.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9705.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9853.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9494.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1196.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5060.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/7047.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3394.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2738.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/9035.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/2338.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/3809.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/5134.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8267.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8639.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6544.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/6706.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/1133.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/test/8536.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/7429.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/6427.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/7144.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/6186.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/5244.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/8229.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/2758.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/9532.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/6471.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/7506.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/7640.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/6782.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/9069.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/1266.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/8119.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/5861.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/5394.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/4276.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/7520.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/9464.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/7571.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/2556.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/4123.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/1114.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/5944.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/5167.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/1410.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/8935.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/8418.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/9031.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/3108.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/8643.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/8205.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/2433.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/5523.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/4357.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/3261.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/6073.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/6242.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/3100.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/1304.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/9004.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/3071.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/8963.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/4822.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/8068.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/5273.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/5344.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/2200.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/7870.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/9714.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/8155.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/9014.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/9068.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/1100.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/7861.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/1143.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/8176.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/8046.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/2606.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/6201.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/1475.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/7634.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/5392.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/6704.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/6273.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/9625.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/8730.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/3359.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/4964.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/2108.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/5034.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/1468.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/4691.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/4048.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/8498.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/3050.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/4713.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/4939.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/5197.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/2205.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/6065.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/6779.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/8492.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/6929.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/5196.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/4041.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/9703.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/5931.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/7030.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/7420.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/3292.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset_beat/train/1994.fused.full.npy
# ...
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6118.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/5625.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2769.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/1491.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/1888.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/4022.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/1684.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/9521.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/5362.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2121.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6589.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/3404.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2632.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6850.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6385.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2498.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2503.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/9790.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/9039.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7624.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6642.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8084.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8045.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/9207.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7486.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/3905.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8742.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/5019.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/3211.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/4367.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2776.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/1825.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/1237.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6088.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2158.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8868.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/4853.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/4655.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8442.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7396.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/5641.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8424.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/3839.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6161.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/4268.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7205.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7178.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/4742.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/9306.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8883.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/9744.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6355.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/3028.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2674.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6763.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/4726.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2948.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2646.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6476.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/9116.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7762.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/5125.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/9130.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/4020.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/9710.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/5823.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2958.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2692.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2254.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/4265.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/5497.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/5107.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8970.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/4991.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/3590.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/1542.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8031.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/5091.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/5598.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6463.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7663.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7801.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/1830.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6564.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2305.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2123.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7761.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2148.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/4034.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/4734.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/1054.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8785.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/3678.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/4928.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7500.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/9859.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/5042.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2582.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7013.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/1553.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7988.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6817.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2141.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6824.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/3987.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/3318.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/9502.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2796.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7286.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/5694.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/1424.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8275.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/5530.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8204.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7130.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/4578.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/4838.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8362.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8481.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/9823.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/9761.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/3113.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7492.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8714.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/9365.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8649.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/4176.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/4594.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7876.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/5965.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6808.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8865.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6241.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/9794.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8641.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/3625.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6212.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2619.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/3412.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2351.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/2862.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6356.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/3979.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/1190.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/1149.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7311.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8238.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8012.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/3814.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/3380.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6687.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/3728.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8977.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/1815.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7096.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8244.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/8490.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/1193.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/9390.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/3539.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/1390.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/7239.fused.full.npy
# /kaggle/input/patreco3-multitask-affective-music/data/multitask_dataset/train/6806.fused.full.npy

# %%
# Helper functions to read fused, mel, and chromagram
def read_fused_spectrogram(spectrogram_file):
    spectrogram = np.load(spectrogram_file)
    return spectrogram.T


def read_mel_spectrogram(spectrogram_file):
    spectrogram = np.load(spectrogram_file)[:128]
    return spectrogram.T

    
def read_chromagram(spectrogram_file):
    spectrogram = np.load(spectrogram_file)[128:]
    return spectrogram.T

# %%
def get_files_labels(txt,emotion_type):
    with open(txt, 'r') as fd:
        lines = [l.rstrip().split(',') for l in fd.readlines()[1:]]
        files, labels = [], []
        for l in lines:
            if emotion_type == "Valence":
                label = float(l[1])
            elif emotion_type == "Energy":
                label = float(l[2]) 
            elif emotion_type == "Danceability":
                label = float(l[3])
            elif emotion_type == "All":
                label = [float(l[1]),float(l[2]),float(l[3])]
            else: raise TypeError("Wrong emotion type!")
            if not label:
                continue
            # Kaggle automatically unzips the npy.gz format so this hack is needed
            _id = l[0]
            npy_file = '{}.fused.full.npy'.format(_id)
            files.append(npy_file)
            labels.append(label)
        return files, labels

# %% [markdown]
# ### Βήμα 8: Εκτίμηση συναισθήματος-συμπεριφοράς με παλινδρόμηση

# %%
import copy
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset
from torch.utils.data import SubsetRandomSampler, DataLoader
import re

# TODO: Comment on how the train and validation splits are created.
# TODO: It's useful to set the seed when debugging but when experimenting ALWAYS set seed=None. Why?
def torch_train_val_test_split(
        dataset, batch_train, batch_eval, batch_test,
        val_size=.15, test_size = .15, shuffle=True, seed=None):
    
    # Creating data indices for training and validation splits:
    dataset_size = len(dataset)
    indices = list(range(dataset_size))
    val_split = int(np.floor(val_size * dataset_size))
    test_split = int(np.floor(test_size * dataset_size))

    if shuffle:
        np.random.seed(seed)
        np.random.shuffle(indices)
        
    val_indices = indices[:val_split]
    test_indices = indices[val_split:(val_split+test_split)]
    train_indices = indices[(val_split+test_split):]

    # Creating PT data samplers and loaders:
    train_sampler = SubsetRandomSampler(train_indices)
    val_sampler = SubsetRandomSampler(val_indices)
    test_sampler = SubsetRandomSampler(test_indices)

    train_loader = DataLoader(dataset,
                              batch_size=batch_train,
                              sampler=train_sampler)
    val_loader = DataLoader(dataset,
                            batch_size=batch_eval,
                            sampler=val_sampler)
    test_loader = DataLoader(dataset,
                            batch_size=batch_test,
                            sampler=test_sampler)
    
    return train_loader, val_loader, test_loader


# TODO: Comment on why padding is needed
class PaddingTransform(object):
    def __init__(self, max_length, padding_value=0):
        self.max_length = max_length
        self.padding_value = padding_value

    def __call__(self, s):
        if len(s) == self.max_length:
            return s

        if len(s) > self.max_length:
            return s[:self.max_length]
        
        if len(s) < self.max_length:
            s1 = copy.deepcopy(s)
            pad = np.zeros((self.max_length - s.shape[0], s.shape[1]), dtype=np.float32)
            s1 = np.vstack((s1, pad))
            return s1

# Pytorch Dataset Class for creating the dataset
class MultitaskDataset(Dataset):
    def __init__(self, path, max_length=-1, read_spec_fn=read_fused_spectrogram, emotion_type = "Valence"):
        self.index = os.path.join(path, "train_labels.txt")
        self.files, labels = get_files_labels(self.index,emotion_type)
        self.feats = [read_spec_fn(os.path.join(path+"train", f)) for f in self.files] # lista apo arrays opoy to kathe ena einai to mel / chromogram
        self.feat_dim = self.feats[0].shape[1]
        self.lengths = [len(i) for i in self.feats]
        self.max_length = max(self.lengths) if max_length <= 0 else max_length
        self.zero_pad_and_stack = PaddingTransform(self.max_length)
        if isinstance(labels, (list, tuple)):
            self.labels = np.array(labels)

    def __getitem__(self, item):
        # TODO: Inspect output and comment on how the output is formatted
        l = min(self.lengths[item], self.max_length)
        return self.zero_pad_and_stack(self.feats[item]), self.labels[item], l

    def __len__(self):
        return len(self.labels)

# %%
def fit(model, train_loader, validation_loader, loss_fn, num_epochs, patience = 10, batch_size = 32, L2 = 0, earlyStopping = True, nn_type = "LSTM"):
    
    # Adam Optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=L2)
    
    min_val_loss = np.Inf
    
    early_stop = False

    for epoch in range(num_epochs):

        model.train()
        train_loss = 0
        for batch, labels, lengths in train_loader:
            if torch.cuda.is_available():
                batch = batch.cuda()
                labels = labels.cuda()
                lengths = lengths.cuda()
            # Clear gradients
            optimizer.zero_grad()

            # Calculate output
            if nn_type == "LSTM":
                output = model(batch,lengths)
            else:
                output = model(batch)
            # Calculate loss
            loss = loss_fn(np.squeeze(output), labels)
            
            # Calculating gradients
            loss.backward()

            # Update parameters
            optimizer.step()
        
            train_loss += loss.item()
        train_loss /= len(train_loader)

        model.eval()
        valid_loss = 0
        with torch.no_grad():
            for batch, labels, lengths in validation_loader:
                if torch.cuda.is_available():
                        batch = batch.cuda()
                        labels = labels.cuda()
                        lengths = lengths.cuda()
                # Calculate output
                if nn_type == "LSTM":
                    output = model(batch,lengths)
                else:
                    output = model(batch)
                    
                # Calculate MSE loss
                loss = loss_fn(np.squeeze(output), labels)
                valid_loss += loss.item()
        valid_loss /= len(validation_loader)

        # Check for use of earlyStopping
        if earlyStopping:
            if valid_loss < min_val_loss: # improvement
                torch.save(model.state_dict(),"best.pt")
                epochs_no_improve = 0
                min_val_loss = valid_loss
            else: # no improvement
                epochs_no_improve +=1 
            if epochs_no_improve == patience:
                early_stop = True

        print("Epoch: {}/{}".format(epoch+1,num_epochs), "...", "\033[1mTraining loss: {:.6f}\033[0m".format(train_loss), "...", "\033[1mValidation loss: {:.6f}\033[0m".format(valid_loss))

        # Check early stopping condition
        if early_stop and earlyStopping:
            print('Early stopping!')
            print('Stopped')
            break

    return

# %%
from scipy.stats import spearmanr

def find_spearman_correlation(model, data_loader,nn_type="LSTM"):
    model.load_state_dict(torch.load("best.pt"))
    model.eval()
    targets, predictions = [], []
    with torch.no_grad():
            for batch, labels, lengths in data_loader:
                if torch.cuda.is_available():
                        batch = batch.cuda()
                        labels = labels.cuda()
                        lengths = lengths.cuda()
                if nn_type == "LSTM":
                    output = model(batch,lengths)
                else:
                    output = model(batch)
                predictions.extend(output.cpu().numpy())
                targets.extend(labels.cpu().numpy())
    spearman_correlation = spearmanr(predictions,targets).correlation
    return abs(spearman_correlation)

# %% [markdown]
# #### (a)

# %%
import torch
import torch.nn as nn

class BasicLSTM(nn.Module):
    
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim, bidirectional=False, dropout = 0):

        super(BasicLSTM, self).__init__()
        self.bidirectional = bidirectional                                       # Parameter that defines if our model is unidirectional or bidiretional (bidirectional if True)
        self.feature_size = hidden_dim*2 if self.bidirectional else hidden_dim   # Feature size

        self.hidden_dim = hidden_dim         # Hidden dimensions
        self.num_layers = num_layers         # Number of hidden layers
        
        self.lstm    = nn.LSTM(input_dim, hidden_dim, num_layers, dropout = dropout, bidirectional=self.bidirectional, batch_first=True)  # Define LSTM model
        self.linear  = nn.Linear(self.feature_size, output_dim) # Apply linear transformation before output

    def forward(self, x, lengths):

        h0 = torch.zeros(self.num_layers*(1+int(self.bidirectional)), x.size(0), self.hidden_dim).double().requires_grad_()           # Initialize hidden state with zeros
        c0 = torch.zeros(self.num_layers*(1+int(self.bidirectional)), x.size(0), self.hidden_dim).double().requires_grad_()           # Initialize cell state
        if torch.cuda.is_available():
            h0 = h0.cuda()
            c0 = c0.cuda()
        out, (hn, cn) = self.lstm(x, (h0.detach(), c0.detach()))
        last_outputs = self.last_timestep(out,lengths,self.bidirectional)
        last_outputs = self.linear(last_outputs)
        return last_outputs

    def last_timestep(self, outputs, lengths, bidirectional=False):

        if bidirectional:
            forward, backward = self.split_directions(outputs)
            last_forward = self.last_by_index(forward, lengths)
            last_backward = backward[:, 0, :]
            # Concatenate and return - maybe add more functionalities like average
            return torch.cat((last_forward, last_backward), dim=-1)

        else:
            return self.last_by_index(outputs, lengths)

    @staticmethod
    def split_directions(outputs):

        direction_size = int(outputs.size(-1) / 2)
        forward = outputs[:, :, :direction_size]
        backward = outputs[:, :, direction_size:]
        return forward, backward

    @staticmethod
    def last_by_index(outputs, lengths):

        idx = (lengths - 1).view(-1, 1).expand(outputs.size(0),
                                               outputs.size(2)).unsqueeze(1)
        return outputs.gather(1, idx).squeeze()

# %%
import torch
import torch.nn as nn

class ConvNet(nn.Module):
    
    def __init__(self, in_channels=1, out_channels=32, in_features=6144, output_dim=1):
        
        super(ConvNet,self).__init__()
        self.conv1 = nn.Sequential(                                                         # Define a sequential architecture
            nn.Conv2d(in_channels, out_channels*1, kernel_size=3,padding=1),                # 1st convolutional layer
            nn.BatchNorm2d(out_channels*1),                                                 # 1st Batch normalization layer
            nn.ReLU(),                                                                      # Relu activation function
            nn.MaxPool2d(kernel_size=2))                                                    # Max Pooling with kernel size = 2
        
        self.conv2 = nn.Sequential(                                                         # Define a sequential layer
            nn.Conv2d(out_channels*1, out_channels*2, kernel_size=3,padding=1),             # 2nd convolutional layer
            nn.BatchNorm2d(out_channels*2),                                                 # 2nd Batch normalization layer
            nn.ReLU(),                                                                      # Relu activation function
            nn.MaxPool2d(kernel_size=2))                                                    # Max Pooling layer with kernel size = 2
        
        self.conv3 = nn.Sequential(                                                         # Define a sequential architecture
            nn.Conv2d(out_channels*2, out_channels*3, kernel_size=3,padding=1),             # 3rd convolutional layer
            nn.BatchNorm2d(out_channels*3),                                                 # 3rd Batch normalization layer
            nn.ReLU(),                                                                      # Relu activation function
            nn.MaxPool2d(kernel_size=2))                                                    # Max Pooling with kernel size = 2
        
        self.conv4 = nn.Sequential(                                                         # Define a sequential architecture
            nn.Conv2d(out_channels*3, out_channels*4, kernel_size=3, stride=1, padding=1),  # 4th convolutional layer
            nn.BatchNorm2d(out_channels*4),                                                 # 4th Batch normalization layer
            nn.ReLU(),                                                                      # Max Pooling with kernel size = 2
            nn.MaxPool2d(kernel_size=2))            
        
        self.linear1 = nn.Linear(in_features,1024)                                          # 1st linear layer
        self.linear2 = nn.Linear(1024,512)                                                  # 2nd linear layer
        self.linear3 = nn.Linear(512,output_dim)                                            # 3rd linear layer

    def forward(self, x):
        
        x = x.view(x.size(0), 1, x.size(1), x.size(2))
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        
        x = x.reshape(x.size(0),-1)
        x = self.linear1(x)
        x = self.linear2(x)
        x = self.linear3(x)
        return x

# %% [markdown]
# ### (b) Valence

# %%
# Create multitask dataset for valence estimation
multitask_valence = MultitaskDataset(
         '../input/patreco3-multitask-affective-music/data/multitask_dataset_beat/',
         max_length=-1,
         read_spec_fn=read_mel_spectrogram,
         emotion_type="Valence")
    
train_loader_multitask_valence, val_loader_multitask_valence, test_loader_multitask_valence = torch_train_val_test_split(multitask_valence, 32 ,32, 32, val_size=.15, test_size=.15)

# %%
# Create LSTM
input_dim = 128     # input dimension
hidden_dim = 256    # hidden layer dimension
layer_dim = 2       # number of hidden layers
output_dim = 1      # output dimension

# Number of epochs
num_epochs = 100

# MSE Entropy Loss 
loss_fn = nn.MSELoss()

# Define model
model = BasicLSTM(input_dim, hidden_dim, layer_dim, output_dim, bidirectional=True, dropout=0.2).double()

if torch.cuda.is_available():
    model = model.cuda()
    
# Fit
fit(model, train_loader_multitask_valence, val_loader_multitask_valence, loss_fn, num_epochs, L2 = 0, earlyStopping=True)
# Out:
# Epoch: 1/100 ... Training loss: 0.086830 ... Validation loss: 0.061811
# Epoch: 2/100 ... Training loss: 0.066524 ... Validation loss: 0.067006
# Epoch: 3/100 ... Training loss: 0.062203 ... Validation loss: 0.057350
# Epoch: 4/100 ... Training loss: 0.059645 ... Validation loss: 0.060540
# Epoch: 5/100 ... Training loss: 0.059140 ... Validation loss: 0.062948
# Epoch: 6/100 ... Training loss: 0.059306 ... Validation loss: 0.060527
# Epoch: 7/100 ... Training loss: 0.057271 ... Validation loss: 0.061907
# Epoch: 8/100 ... Training loss: 0.054953 ... Validation loss: 0.057534
# Epoch: 9/100 ... Training loss: 0.051447 ... Validation loss: 0.056682
# Epoch: 10/100 ... Training loss: 0.055789 ... Validation loss: 0.056282
# Epoch: 11/100 ... Training loss: 0.052985 ... Validation loss: 0.058381
# Epoch: 12/100 ... Training loss: 0.051017 ... Validation loss: 0.072142
# Epoch: 13/100 ... Training loss: 0.049633 ... Validation loss: 0.060085
# Epoch: 14/100 ... Training loss: 0.048558 ... Validation loss: 0.057517
# Epoch: 15/100 ... Training loss: 0.045395 ... Validation loss: 0.067011
# Epoch: 16/100 ... Training loss: 0.042772 ... Validation loss: 0.059527
# Epoch: 17/100 ... Training loss: 0.042964 ... Validation loss: 0.061873
# Epoch: 18/100 ... Training loss: 0.045957 ... Validation loss: 0.078294
# Epoch: 19/100 ... Training loss: 0.042831 ... Validation loss: 0.075108
# Epoch: 20/100 ... Training loss: 0.047636 ... Validation loss: 0.068773
# Early stopping!
# Stopped

# %%
val_spear_corr_lstm_valence = find_spearman_correlation(model, val_loader_multitask_valence)                # Find Spearman Correlation for validation data
test_spear_corr_lstm_valence = find_spearman_correlation(model, test_loader_multitask_valence)              # Find Spearman Correlation for test data

print("Spearman correlation of the best model on \033[1mvalidation data\033[0m is \033[1m{}\033[0m".format(np.round(val_spear_corr_lstm_valence,3)))
print("Spearman correlation of the best model on \033[1mtest data\033[0m is \033[1m{}\033[0m".format(np.round(test_spear_corr_lstm_valence,3)))
# Out:
# Spearman correlation of the best model on validation data is 0.207
# Spearman correlation of the best model on test data is 0.199

# %%
# Create ConvNet
in_channels = 1     # number of channels
out_channels = 32   # hidden layer dimension
in_features = 6144  # number of features
output_dim = 1      # output dimension

# Number of epochs
num_epochs = 100

# MSE Entropy Loss 
loss_fn = nn.MSELoss()

# Define model 
model = ConvNet(in_channels, out_channels, in_features, output_dim).double()

if torch.cuda.is_available():
    model = model.cuda()

# Fit
fit(model, train_loader_multitask_valence, val_loader_multitask_valence, loss_fn, num_epochs, L2 = 0, earlyStopping=True, nn_type="CNN")
# Out:
# Epoch: 1/100 ... Training loss: 1.850434 ... Validation loss: 0.082244
# Epoch: 2/100 ... Training loss: 0.124487 ... Validation loss: 0.055848
# Epoch: 3/100 ... Training loss: 0.059590 ... Validation loss: 0.049550
# Epoch: 4/100 ... Training loss: 0.052749 ... Validation loss: 0.049244
# Epoch: 5/100 ... Training loss: 0.050537 ... Validation loss: 0.047056
# Epoch: 6/100 ... Training loss: 0.048324 ... Validation loss: 0.043278
# Epoch: 7/100 ... Training loss: 0.044959 ... Validation loss: 0.042578
# Epoch: 8/100 ... Training loss: 0.044355 ... Validation loss: 0.040801
# Epoch: 9/100 ... Training loss: 0.043827 ... Validation loss: 0.044818
# Epoch: 10/100 ... Training loss: 0.040286 ... Validation loss: 0.048144
# Epoch: 11/100 ... Training loss: 0.039619 ... Validation loss: 0.038171
# Epoch: 12/100 ... Training loss: 0.037609 ... Validation loss: 0.041661
# Epoch: 13/100 ... Training loss: 0.035139 ... Validation loss: 0.044746
# Epoch: 14/100 ... Training loss: 0.036350 ... Validation loss: 0.040143
# Epoch: 15/100 ... Training loss: 0.036011 ... Validation loss: 0.044781
# Epoch: 16/100 ... Training loss: 0.031102 ... Validation loss: 0.039805
# Epoch: 17/100 ... Training loss: 0.029430 ... Validation loss: 0.042282
# Epoch: 18/100 ... Training loss: 0.027994 ... Validation loss: 0.044589
# Epoch: 19/100 ... Training loss: 0.025716 ... Validation loss: 0.042689
# Epoch: 20/100 ... Training loss: 0.028235 ... Validation loss: 0.040100
# Epoch: 21/100 ... Training loss: 0.022498 ... Validation loss: 0.041346
# Early stopping!
# Stopped

# %%
val_spear_corr_conv_valence = find_spearman_correlation(model, val_loader_multitask_valence, nn_type="CNN")              # Find Spearman Correlation for validation data
test_spear_corr_conv_valence = find_spearman_correlation(model, test_loader_multitask_valence, nn_type="CNN")            # Find Spearman Correlation for test data

print("Spearman correlation of the best model on \033[1mvalidation data\033[0m is \033[1m{}\033[0m".format(np.round(val_spear_corr_conv_valence,3)))
print("Spearman correlation of the best model on \033[1mtest data\033[0m is \033[1m{}\033[0m".format(np.round(test_spear_corr_conv_valence,3)))
# Out:
# Spearman correlation of the best model on validation data is 0.573
# Spearman correlation of the best model on test data is 0.574

# %% [markdown]
# ### (c) Energy

# %%
# Create multitask dataset for energy estimation
multitask_energy = MultitaskDataset(
         '../input/patreco3-multitask-affective-music/data/multitask_dataset_beat/',
         max_length=-1,
         read_spec_fn=read_mel_spectrogram,
         emotion_type="Energy")
    
train_loader_multitask_energy, val_loader_multitask_energy, test_loader_multitask_energy = torch_train_val_test_split(multitask_energy, 32 ,32, 32, val_size=.15, test_size=.15)

# %%
# Create LSTM
input_dim = 128     # input dimension
hidden_dim = 256    # hidden layer dimension
layer_dim = 2       # number of hidden layers
output_dim = 1      # output dimension

# Number of epochs
num_epochs = 100

# MSE Entropy Loss 
loss_fn = nn.MSELoss()

# Define model
model = BasicLSTM(input_dim, hidden_dim, layer_dim, output_dim, bidirectional=True, dropout=0.2).double()

if torch.cuda.is_available():
    model = model.cuda()
    
# Fit
fit(model, train_loader_multitask_energy, val_loader_multitask_energy, loss_fn, num_epochs, L2 = 0, earlyStopping=True)
# Out:
# Epoch: 1/100 ... Training loss: 0.123437 ... Validation loss: 0.062702
# Epoch: 2/100 ... Training loss: 0.058866 ... Validation loss: 0.063574
# Epoch: 3/100 ... Training loss: 0.043997 ... Validation loss: 0.043453
# Epoch: 4/100 ... Training loss: 0.037885 ... Validation loss: 0.038051
# Epoch: 5/100 ... Training loss: 0.035133 ... Validation loss: 0.041903
# Epoch: 6/100 ... Training loss: 0.032693 ... Validation loss: 0.042467
# Epoch: 7/100 ... Training loss: 0.032271 ... Validation loss: 0.052379
# Epoch: 8/100 ... Training loss: 0.030765 ... Validation loss: 0.045850
# Epoch: 9/100 ... Training loss: 0.030997 ... Validation loss: 0.038896
# Epoch: 10/100 ... Training loss: 0.028435 ... Validation loss: 0.038625
# Epoch: 11/100 ... Training loss: 0.026983 ... Validation loss: 0.046093
# Epoch: 12/100 ... Training loss: 0.029423 ... Validation loss: 0.042020
# Epoch: 13/100 ... Training loss: 0.029133 ... Validation loss: 0.049030
# Epoch: 14/100 ... Training loss: 0.026274 ... Validation loss: 0.036870
# Epoch: 15/100 ... Training loss: 0.025333 ... Validation loss: 0.042093
# Epoch: 16/100 ... Training loss: 0.022518 ... Validation loss: 0.038044
# Epoch: 17/100 ... Training loss: 0.022433 ... Validation loss: 0.039702
# Epoch: 18/100 ... Training loss: 0.020415 ... Validation loss: 0.043048
# Epoch: 19/100 ... Training loss: 0.022476 ... Validation loss: 0.045566
# Epoch: 20/100 ... Training loss: 0.024925 ... Validation loss: 0.035902
# Epoch: 21/100 ... Training loss: 0.021778 ... Validation loss: 0.042149
# Epoch: 22/100 ... Training loss: 0.023723 ... Validation loss: 0.036383
# Epoch: 23/100 ... Training loss: 0.019252 ... Validation loss: 0.037014
# Epoch: 24/100 ... Training loss: 0.017225 ... Validation loss: 0.036362
# Epoch: 25/100 ... Training loss: 0.017815 ... Validation loss: 0.042128
# Epoch: 26/100 ... Training loss: 0.017504 ... Validation loss: 0.036504
# Epoch: 27/100 ... Training loss: 0.016756 ... Validation loss: 0.041063
# Epoch: 28/100 ... Training loss: 0.015683 ... Validation loss: 0.045832
# Epoch: 29/100 ... Training loss: 0.017408 ... Validation loss: 0.036247
# Epoch: 30/100 ... Training loss: 0.015954 ... Validation loss: 0.042232
# Early stopping!
# Stopped

# %%
val_spear_corr_lstm_energy = find_spearman_correlation(model, val_loader_multitask_energy)                  # Find Spearman Correlation for validation data
test_spear_corr_lstm_energy = find_spearman_correlation(model, test_loader_multitask_energy)                # Find Spearman Correlation for test data

print("Spearman correlation of the best model on \033[1mvalidation data\033[0m is \033[1m{}\033[0m".format(np.round(val_spear_corr_lstm_energy,3)))
print("Spearman correlation of the best model on \033[1mtest data\033[0m is \033[1m{}\033[0m".format(np.round(test_spear_corr_lstm_energy,3)))
# Out:
# Spearman correlation of the best model on validation data is 0.655
# Spearman correlation of the best model on test data is 0.694

# %%
# Create ConvNet
in_channels = 1     # number of channels
out_channels = 32   # hidden layer dimension
in_features = 6144  # number of features
output_dim = 1      # output dimension

# Number of epochs
num_epochs = 100

# MSE Entropy Loss 
loss_fn = nn.MSELoss()

# Define model
model = ConvNet(in_channels, out_channels, in_features, output_dim).double()

if torch.cuda.is_available():
    model = model.cuda()

# Fit
fit(model, train_loader_multitask_energy, val_loader_multitask_energy, loss_fn, num_epochs, L2 = 0, earlyStopping=True, nn_type="CNN")
# Out:
# Epoch: 1/100 ... Training loss: 1.704581 ... Validation loss: 0.051251
# Epoch: 2/100 ... Training loss: 0.098633 ... Validation loss: 0.035719
# Epoch: 3/100 ... Training loss: 0.041111 ... Validation loss: 0.049047
# Epoch: 4/100 ... Training loss: 0.031389 ... Validation loss: 0.035603
# Epoch: 5/100 ... Training loss: 0.028050 ... Validation loss: 0.029555
# Epoch: 6/100 ... Training loss: 0.026454 ... Validation loss: 0.031243
# Epoch: 7/100 ... Training loss: 0.024484 ... Validation loss: 0.028745
# Epoch: 8/100 ... Training loss: 0.024513 ... Validation loss: 0.041472
# Epoch: 9/100 ... Training loss: 0.024940 ... Validation loss: 0.031101
# Epoch: 10/100 ... Training loss: 0.022298 ... Validation loss: 0.033508
# Epoch: 11/100 ... Training loss: 0.021270 ... Validation loss: 0.029100
# Epoch: 12/100 ... Training loss: 0.021494 ... Validation loss: 0.028301
# Epoch: 13/100 ... Training loss: 0.021302 ... Validation loss: 0.028577
# Epoch: 14/100 ... Training loss: 0.021965 ... Validation loss: 0.029345
# Epoch: 15/100 ... Training loss: 0.020799 ... Validation loss: 0.028432
# Epoch: 16/100 ... Training loss: 0.017305 ... Validation loss: 0.029052
# Epoch: 17/100 ... Training loss: 0.017594 ... Validation loss: 0.032761
# Epoch: 18/100 ... Training loss: 0.017980 ... Validation loss: 0.029075
# Epoch: 19/100 ... Training loss: 0.015725 ... Validation loss: 0.025862
# Epoch: 20/100 ... Training loss: 0.018733 ... Validation loss: 0.027292
# Epoch: 21/100 ... Training loss: 0.014818 ... Validation loss: 0.029052
# Epoch: 22/100 ... Training loss: 0.014448 ... Validation loss: 0.030685
# Epoch: 23/100 ... Training loss: 0.012975 ... Validation loss: 0.033017
# Epoch: 24/100 ... Training loss: 0.014948 ... Validation loss: 0.033986
# Epoch: 25/100 ... Training loss: 0.014246 ... Validation loss: 0.033541
# Epoch: 26/100 ... Training loss: 0.016617 ... Validation loss: 0.031275
# Epoch: 27/100 ... Training loss: 0.012965 ... Validation loss: 0.031937
# Epoch: 28/100 ... Training loss: 0.013721 ... Validation loss: 0.028130
# Epoch: 29/100 ... Training loss: 0.009137 ... Validation loss: 0.031597
# Early stopping!
# Stopped

# %%
val_spear_corr_conv_energy = find_spearman_correlation(model, val_loader_multitask_energy, nn_type="CNN")                   # Find Spearman Correlation for validation data
test_spear_corr_conv_energy = find_spearman_correlation(model, test_loader_multitask_energy, nn_type="CNN")                 # Find Spearman Correlation for test data

print("Spearman correlation of the best model on \033[1mvalidation data\033[0m is \033[1m{}\033[0m".format(np.round(val_spear_corr_conv_energy,3)))
print("Spearman correlation of the best model on \033[1mtest data\033[0m is \033[1m{}\033[0m".format(np.round(test_spear_corr_conv_energy,3)))
# Out:
# Spearman correlation of the best model on validation data is 0.754
# Spearman correlation of the best model on test data is 0.738

# %% [markdown]
# ### (d) Danceability

# %%
# Create multitask dataset for danceability estimation
multitask_danceability = MultitaskDataset(
         '../input/patreco3-multitask-affective-music/data/multitask_dataset_beat/',
         max_length=-1,
         read_spec_fn=read_mel_spectrogram,
         emotion_type="Danceability")
    
train_loader_multitask_danceability, val_loader_multitask_danceability, test_loader_multitask_danceability = torch_train_val_test_split(multitask_danceability, 32 ,32, 32, val_size=.15, test_size=.15)

# %%
# Create LSTM
input_dim = 128     # input dimension
hidden_dim = 256    # hidden layer dimension
layer_dim = 2       # number of hidden layers
output_dim = 1      # output dimension

# Number of epochs
num_epochs = 100

# MSE Entropy Loss 
loss_fn = nn.MSELoss()

# Define model
model = BasicLSTM(input_dim, hidden_dim, layer_dim, output_dim, bidirectional=True, dropout=0.2).double()

if torch.cuda.is_available():
    model = model.cuda()
    
# Fit
fit(model, train_loader_multitask_danceability, val_loader_multitask_danceability, loss_fn, num_epochs, L2 = 0, earlyStopping=True)
# Out:
# Epoch: 1/100 ... Training loss: 0.075323 ... Validation loss: 0.027022
# Epoch: 2/100 ... Training loss: 0.029611 ... Validation loss: 0.031722
# Epoch: 3/100 ... Training loss: 0.026962 ... Validation loss: 0.026380
# Epoch: 4/100 ... Training loss: 0.026091 ... Validation loss: 0.023286
# Epoch: 5/100 ... Training loss: 0.025071 ... Validation loss: 0.022678
# Epoch: 6/100 ... Training loss: 0.024295 ... Validation loss: 0.022979
# Epoch: 7/100 ... Training loss: 0.024571 ... Validation loss: 0.024720
# Epoch: 8/100 ... Training loss: 0.023317 ... Validation loss: 0.022148
# Epoch: 9/100 ... Training loss: 0.022204 ... Validation loss: 0.022466
# Epoch: 10/100 ... Training loss: 0.021773 ... Validation loss: 0.024230
# Epoch: 11/100 ... Training loss: 0.021778 ... Validation loss: 0.022237
# Epoch: 12/100 ... Training loss: 0.020519 ... Validation loss: 0.022274
# Epoch: 13/100 ... Training loss: 0.020701 ... Validation loss: 0.020447
# Epoch: 14/100 ... Training loss: 0.021627 ... Validation loss: 0.019949
# Epoch: 15/100 ... Training loss: 0.019199 ... Validation loss: 0.022256
# Epoch: 16/100 ... Training loss: 0.018121 ... Validation loss: 0.021993
# Epoch: 17/100 ... Training loss: 0.016505 ... Validation loss: 0.021359
# Epoch: 18/100 ... Training loss: 0.015982 ... Validation loss: 0.021692
# Epoch: 19/100 ... Training loss: 0.016916 ... Validation loss: 0.019826
# Epoch: 20/100 ... Training loss: 0.016446 ... Validation loss: 0.021950
# Epoch: 21/100 ... Training loss: 0.015778 ... Validation loss: 0.023886
# Epoch: 22/100 ... Training loss: 0.015698 ... Validation loss: 0.024784
# Epoch: 23/100 ... Training loss: 0.016018 ... Validation loss: 0.030475
# Epoch: 24/100 ... Training loss: 0.015179 ... Validation loss: 0.022114
# Epoch: 25/100 ... Training loss: 0.014543 ... Validation loss: 0.022997
# Epoch: 26/100 ... Training loss: 0.014049 ... Validation loss: 0.026458
# Epoch: 27/100 ... Training loss: 0.014453 ... Validation loss: 0.022678
# Epoch: 28/100 ... Training loss: 0.014602 ... Validation loss: 0.024266
# Epoch: 29/100 ... Training loss: 0.012387 ... Validation loss: 0.028270
# Early stopping!
# Stopped

# %%
val_spear_corr_lstm_danceability = find_spearman_correlation(model, val_loader_multitask_danceability)            # Find Spearman Correlation for validation data
test_spear_corr_lstm_danceability = find_spearman_correlation(model, test_loader_multitask_danceability)          # Find Spearman Correlation for test data

print("Spearman correlation of the best model on \033[1mvalidation data\033[0m is \033[1m{}\033[0m".format(np.round(val_spear_corr_lstm_danceability,3)))
print("Spearman correlation of the best model on \033[1mtest data\033[0m is \033[1m{}\033[0m".format(np.round(test_spear_corr_lstm_danceability,3)))
# Out:
# Spearman correlation of the best model on validation data is 0.575
# Spearman correlation of the best model on test data is 0.43

# %%
# Create ConvNet
in_channels = 1     # number of channels
out_channels = 32   # hidden layer dimension
in_features = 6144  # number of features
output_dim = 1      # output dimension

# Number of epochs
num_epochs = 100

# MSE Entropy Loss 
loss_fn = nn.MSELoss()

# Define model
model = ConvNet(in_channels, out_channels, in_features, output_dim).double()

if torch.cuda.is_available():
    model = model.cuda()

# Fit
fit(model, train_loader_multitask_danceability, val_loader_multitask_danceability, loss_fn, num_epochs, L2 = 0, earlyStopping=True, nn_type="CNN")
# Out:
# Epoch: 1/100 ... Training loss: 1.681934 ... Validation loss: 0.049000
# Epoch: 2/100 ... Training loss: 0.081318 ... Validation loss: 0.042864
# Epoch: 3/100 ... Training loss: 0.030802 ... Validation loss: 0.030932
# Epoch: 4/100 ... Training loss: 0.024819 ... Validation loss: 0.024369
# Epoch: 5/100 ... Training loss: 0.022725 ... Validation loss: 0.025282
# Epoch: 6/100 ... Training loss: 0.021195 ... Validation loss: 0.020471
# Epoch: 7/100 ... Training loss: 0.019989 ... Validation loss: 0.021000
# Epoch: 8/100 ... Training loss: 0.020561 ... Validation loss: 0.025161
# Epoch: 9/100 ... Training loss: 0.018257 ... Validation loss: 0.019958
# Epoch: 10/100 ... Training loss: 0.017649 ... Validation loss: 0.018323
# Epoch: 11/100 ... Training loss: 0.016794 ... Validation loss: 0.020910
# Epoch: 12/100 ... Training loss: 0.016414 ... Validation loss: 0.019389
# Epoch: 13/100 ... Training loss: 0.015190 ... Validation loss: 0.019486
# Epoch: 14/100 ... Training loss: 0.014808 ... Validation loss: 0.020771
# Epoch: 15/100 ... Training loss: 0.014808 ... Validation loss: 0.016975
# Epoch: 16/100 ... Training loss: 0.013317 ... Validation loss: 0.018207
# Epoch: 17/100 ... Training loss: 0.012628 ... Validation loss: 0.017065
# Epoch: 18/100 ... Training loss: 0.012483 ... Validation loss: 0.021932
# Epoch: 19/100 ... Training loss: 0.010911 ... Validation loss: 0.022257
# Epoch: 20/100 ... Training loss: 0.010341 ... Validation loss: 0.018784
# Epoch: 21/100 ... Training loss: 0.009544 ... Validation loss: 0.018954
# Epoch: 22/100 ... Training loss: 0.009853 ... Validation loss: 0.022423
# Epoch: 23/100 ... Training loss: 0.010236 ... Validation loss: 0.020748
# Epoch: 24/100 ... Training loss: 0.008346 ... Validation loss: 0.019703
# Epoch: 25/100 ... Training loss: 0.007047 ... Validation loss: 0.018942
# Early stopping!
# Stopped

# %%
val_spear_corr_conv_danceability = find_spearman_correlation(model, val_loader_multitask_danceability, nn_type="CNN")             # Find Spearman Correlation for validation data
test_spear_corr_conv_danceability = find_spearman_correlation(model, test_loader_multitask_danceability, nn_type="CNN")           # Find Spearman Correlation for test data

print("Spearman correlation of the best model on \033[1mvalidation data\033[0m is \033[1m{}\033[0m".format(np.round(val_spear_corr_conv_danceability,3)))
print("Spearman correlation of the best model on \033[1mtest data\033[0m is \033[1m{}\033[0m".format(np.round(test_spear_corr_conv_danceability,3)))
# Out:
# Spearman correlation of the best model on validation data is 0.654
# Spearman correlation of the best model on test data is 0.587

# %% [markdown]
# ### (e)

# %%
# Calculate Mean Spearman Correlation for LSTM
mean_val_spear_corr_lstm =  (val_spear_corr_lstm_valence + val_spear_corr_lstm_energy + val_spear_corr_lstm_danceability) / 3
mean_test_spear_corr_lstm = (test_spear_corr_lstm_valence + test_spear_corr_lstm_energy + test_spear_corr_lstm_danceability) / 3

print("Mean spearman correlation of LSTM model on \033[1mvalidation data\033[0m is \033[1m{}\033[0m".format(np.round(mean_val_spear_corr_lstm,3)))
print("Mean spearman correlation of LSTM model on \033[1mtest data\033[0m is \033[1m{}\033[0m\n".format(np.round(mean_test_spear_corr_lstm,3)))

# Calculate Mean Spearman Correlation for CNN
mean_val_spear_corr_conv = (val_spear_corr_conv_valence + val_spear_corr_conv_energy + val_spear_corr_conv_danceability) / 3
mean_test_spear_corr_conv = (test_spear_corr_conv_valence + test_spear_corr_conv_energy + test_spear_corr_conv_danceability) / 3

print("Mean spearman correlation of CNN model on \033[1mvalidation data\033[0m is \033[1m{}\033[0m".format(np.round(mean_val_spear_corr_conv,3)))
print("Mean spearman correlation of CNN model on \033[1mtest data\033[0m is \033[1m{}\033[0m".format(np.round(mean_test_spear_corr_conv,3)))
# Out:
# Mean spearman correlation of LSTM model on validation data is 0.479
# Mean spearman correlation of LSTM model on test data is 0.441
#
# Mean spearman correlation of CNN model on validation data is 0.661
# Mean spearman correlation of CNN model on test data is 0.633

# %% [markdown]
# #### (f)

# %%
# Create multitask dataset for emotion_type = "All"
multitask_all = MultitaskDataset(
         '../input/patreco3-multitask-affective-music/data/multitask_dataset_beat/',
         max_length=-1,
         read_spec_fn=read_mel_spectrogram,
         emotion_type="All")
    
train_loader_multitask_all, val_loader_multitask_all, test_loader_multitask_all = torch_train_val_test_split(multitask_all, 32 ,32, 32, val_size=.15, test_size=.15)

# %% [markdown]
# ### Βήμα 9α: Μεταφορά γνώσης (Transfer Learning)

# %%
# Combine similar classes and remove underrepresented classes
class_mapping = {
    'Rock': 'Rock',
    'Psych-Rock': 'Rock',
    'Indie-Rock': None,
    'Post-Rock': 'Rock',
    'Psych-Folk': 'Folk',
    'Folk': 'Folk',
    'Metal': 'Metal',
    'Punk': 'Metal',
    'Post-Punk': None,
    'Trip-Hop': 'Trip-Hop',
    'Pop': 'Pop',
    'Electronic': 'Electronic',
    'Hip-Hop': 'Hip-Hop',
    'Classical': 'Classical',
    'Blues': 'Blues',
    'Chiptune': 'Electronic',
    'Jazz': 'Jazz',
    'Soundtrack': None,
    'International': None,
    'Old-Time': None
}

def get_files_labels(txt, class_mapping=None):
    with open(txt, 'r') as fd:
        lines = [l.rstrip().split('\t') for l in fd.readlines()[1:]]
        files, labels = [], []
        for l in lines:
            label = l[1]
            if class_mapping:
                label = class_mapping[l[1]]
            if not label:
                continue
            # Kaggle automatically unzips the npy.gz format so this hack is needed
            _id = l[0].split('.')[0]
            npy_file = '{}.fused.full.npy'.format(_id)
            files.append(npy_file)
            labels.append(label)
        return files, labels
    
# TODO: Comment on how the train and validation splits are created.
# TODO: It's useful to set the seed when debugging but when experimenting ALWAYS set seed=None. Why?
def torch_train_val_split(
        dataset, batch_train, batch_eval,
        val_size=.2, shuffle=True, seed=None):
    # Creating data indices for training and validation splits:
    dataset_size = len(dataset)
    indices = list(range(dataset_size))
    val_split = int(np.floor(val_size * dataset_size))
    if shuffle:
        np.random.seed(seed)
        np.random.shuffle(indices)
    train_indices = indices[val_split:]
    val_indices = indices[:val_split]

    # Creating PT data samplers and loaders:
    train_sampler = SubsetRandomSampler(train_indices)
    val_sampler = SubsetRandomSampler(val_indices)

    train_loader = DataLoader(dataset,
                              batch_size=batch_train,
                              sampler=train_sampler)
    val_loader = DataLoader(dataset,
                            batch_size=batch_eval,
                            sampler=val_sampler)
    return train_loader, val_loader


class LabelTransformer(LabelEncoder):
    def inverse(self, y):
        try:
            return super(LabelTransformer, self).inverse_transform(y)
        except:
            return super(LabelTransformer, self).inverse_transform([y])

    def transform(self, y):
        try:
            return super(LabelTransformer, self).transform(y)
        except:
            return super(LabelTransformer, self).transform([y])


# TODO: Comment on why padding is needed
class PaddingTransform(object):
    def __init__(self, max_length, padding_value=0):
        self.max_length = max_length
        self.padding_value = padding_value

    def __call__(self, s):
        if len(s) == self.max_length:
            return s

        if len(s) > self.max_length:
            return s[:self.max_length]
        
        if len(s) < self.max_length:
            s1 = copy.deepcopy(s)
            pad = np.zeros((self.max_length - s.shape[0], s.shape[1]), dtype=np.float32)
            s1 = np.vstack((s1, pad))
            return s1

# Pytorch Dataset Class for creating the dataset
class SpectrogramDataset(Dataset):
    def __init__(self, path, class_mapping=None, train=True, max_length=-1, read_spec_fn=read_fused_spectrogram):
        t = 'train' if train else 'test'
        p = os.path.join(path, t)
        self.index = os.path.join(path, "{}_labels.txt".format(t))
        self.files, labels = get_files_labels(self.index, class_mapping)
        self.feats = [read_spec_fn(os.path.join(p, f)) for f in self.files] # lista apo arrays opoy to kathe ena einai to mel / chromogram
        self.feat_dim = self.feats[0].shape[1]
        self.lengths = [len(i) for i in self.feats]
        self.max_length = max(self.lengths) if max_length <= 0 else max_length
        self.zero_pad_and_stack = PaddingTransform(self.max_length)
        self.label_transformer = LabelTransformer()
        if isinstance(labels, (list, tuple)):
            self.labels = np.array(self.label_transformer.fit_transform(labels)).astype('int64')
    def __getitem__(self, item):
        # TODO: Inspect output and comment on how the output is formatted
        l = min(self.lengths[item], self.max_length)
        return self.zero_pad_and_stack(self.feats[item]), self.labels[item], l

    def __len__(self):
        return len(self.labels)

# %%
beat_mel_specs = SpectrogramDataset(
         '../input/patreco3-multitask-affective-music/data/fma_genre_spectrograms_beat/',
         train=True,
         class_mapping=class_mapping,
         max_length=-1,
         read_spec_fn=read_mel_spectrogram)
    
train_loader_beat_mel, val_loader_beat_mel = torch_train_val_split(beat_mel_specs, 32 ,32, val_size=.33)

# %%
# Create ConvNet
in_channels = 1     # number of channels
out_channels = 32   # hidden layer dimension
in_features = 8192  # number of features
output_dim = 10     # output dimension

# Number of epochs
num_epochs = 100

# Cross Entropy Loss 
loss_fn = nn.CrossEntropyLoss()

# Define model
model = ConvNet(in_channels, out_channels, in_features, output_dim).double()

if torch.cuda.is_available():
    model = model.cuda()

# Fit
fit(model, train_loader_beat_mel, val_loader_beat_mel, loss_fn, num_epochs, L2 = 0, earlyStopping=True, nn_type="CNN")
# Out:
# Epoch: 1/100 ... Training loss: 2.126159 ... Validation loss: 1.891392
# Epoch: 2/100 ... Training loss: 1.660126 ... Validation loss: 2.040942
# Epoch: 3/100 ... Training loss: 1.527828 ... Validation loss: 1.731204
# Epoch: 4/100 ... Training loss: 1.358625 ... Validation loss: 1.766555
# Epoch: 5/100 ... Training loss: 1.234710 ... Validation loss: 1.662029
# Epoch: 6/100 ... Training loss: 1.069721 ... Validation loss: 2.059978
# Epoch: 7/100 ... Training loss: 0.955489 ... Validation loss: 2.186075
# Epoch: 8/100 ... Training loss: 0.692885 ... Validation loss: 1.974730
# Epoch: 9/100 ... Training loss: 0.539301 ... Validation loss: 2.020021
# Epoch: 10/100 ... Training loss: 0.332496 ... Validation loss: 2.426549
# Epoch: 11/100 ... Training loss: 0.199253 ... Validation loss: 2.471833
# Epoch: 12/100 ... Training loss: 0.122317 ... Validation loss: 2.342111
# Epoch: 13/100 ... Training loss: 0.069883 ... Validation loss: 2.559273
# Epoch: 14/100 ... Training loss: 0.046363 ... Validation loss: 2.503295
# Epoch: 15/100 ... Training loss: 0.018938 ... Validation loss: 2.535412
# Early stopping!
# Stopped

# %%
model.load_state_dict(torch.load('best.pt'))                # Load best model
model.linear1 = nn.Linear(6144,1024)                        # Change 1st linear layer
model.linear2 = nn.Linear(1024,512)                         # Change 2nd linear layer
model.linear3 = nn.Linear(512,1)                            # Change 3rd linear layer
model = model.double()

if torch.cuda.is_available():
    model = model.cuda()

# Number of epochs
num_epochs = 20

# MSE Entropy Loss 
loss_fn = nn.MSELoss()

# Fit
fit(model, train_loader_multitask_energy, val_loader_multitask_energy, loss_fn, num_epochs, L2 = 0, earlyStopping=True, nn_type="CNN")
# Out:
# Epoch: 1/20 ... Training loss: 1.802361 ... Validation loss: 0.094738
# Epoch: 2/20 ... Training loss: 0.089289 ... Validation loss: 0.036392
# Epoch: 3/20 ... Training loss: 0.034499 ... Validation loss: 0.028505
# Epoch: 4/20 ... Training loss: 0.026652 ... Validation loss: 0.026447
# Epoch: 5/20 ... Training loss: 0.026377 ... Validation loss: 0.025189
# Epoch: 6/20 ... Training loss: 0.025828 ... Validation loss: 0.025931
# Epoch: 7/20 ... Training loss: 0.023339 ... Validation loss: 0.025692
# Epoch: 8/20 ... Training loss: 0.025570 ... Validation loss: 0.028096
# Epoch: 9/20 ... Training loss: 0.022455 ... Validation loss: 0.025504
# Epoch: 10/20 ... Training loss: 0.023366 ... Validation loss: 0.025447
# Epoch: 11/20 ... Training loss: 0.020703 ... Validation loss: 0.029732
# Epoch: 12/20 ... Training loss: 0.024894 ... Validation loss: 0.036639
# Epoch: 13/20 ... Training loss: 0.023978 ... Validation loss: 0.024484
# Epoch: 14/20 ... Training loss: 0.019109 ... Validation loss: 0.033877
# Epoch: 15/20 ... Training loss: 0.019035 ... Validation loss: 0.025926
# Epoch: 16/20 ... Training loss: 0.018323 ... Validation loss: 0.030858
# Epoch: 17/20 ... Training loss: 0.019221 ... Validation loss: 0.028769
# Epoch: 18/20 ... Training loss: 0.017065 ... Validation loss: 0.029615
# Epoch: 19/20 ... Training loss: 0.016759 ... Validation loss: 0.028443
# Epoch: 20/20 ... Training loss: 0.014071 ... Validation loss: 0.025361

# %%
transfer_val_spear_corr = find_spearman_correlation(model, val_loader_multitask_energy, nn_type="CNN")                # Find Spearman Correlation for validation data
transfer_test_spear_corr = find_spearman_correlation(model, test_loader_multitask_energy,nn_type="CNN")               # Find Spearman Correlation for test data

print("Spearman correlation of the best transfer learning model on \033[1mvalidation data\033[0m is \033[1m{}\033[0m".format(np.round(transfer_val_spear_corr,3)))
print("Spearman correlation of the best transfer learning model on \033[1mtest data\033[0m is \033[1m{}\033[0m".format(np.round(transfer_test_spear_corr,3)))
# Out:
# Spearman correlation of the best transfer learning model on validation data is 0.772
# Spearman correlation of the best transfer learning model on test data is 0.725

# %% [markdown]
# ### Βήμα 9β: Εκπαίδευση σε πολλά προβλήματα (Multitask Learning)

# %%
def multitask_fit(model, train_loader, validation_loader, num_epochs, patience = 10, batch_size = 32, L2 = 0, earlyStopping = True, pack_padded_sequence = False, nn_type = "LSTM"):
    
    # MSE Entropy Loss 
    loss_fn = nn.MSELoss()

    # Adam Optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=L2)
    
    min_val_loss = np.Inf
    
    early_stop = False

    for epoch in range(num_epochs):

        model.train()
        train_loss = 0
        if pack_padded_sequence:
            packed_batches, packed_labels, packed_lengths = pack_pad(batch_size)
            train_loader = list(zip(packed_batches, packed_labels, packed_lengths))
        for batch, labels, lengths in train_loader:
            if torch.cuda.is_available():
                batch = batch.cuda()
                labels = labels.cuda()
                lengths = lengths.cuda()
            # Clear gradients
            optimizer.zero_grad()

            # Calculate output
            if nn_type == "LSTM":
                output = model(batch,lengths)
            else:
                output = model(batch)
            
            output_valence = output[:,0]
            output_energy = output[:,1]
            output_danceability = output[:,2]
            
            # Calculate MSE losses
            loss_valence = loss_fn(np.squeeze(output_valence), labels[:,0])
            loss_energy = loss_fn(np.squeeze(output_energy), labels[:,1])
            loss_danceability = loss_fn(np.squeeze(output_danceability), labels[:,2])
            
            loss = loss_valence + loss_energy + loss_danceability
            
            # Calculating gradients
            loss.backward()

            # Update parameters
            optimizer.step()
        
            train_loss += loss.item()
        train_loss /= len(train_loader)

        model.eval()
        valid_loss = 0
        with torch.no_grad():
            for batch, labels, lengths in validation_loader:
                if torch.cuda.is_available():
                        batch = batch.cuda()
                        labels = labels.cuda()
                        lengths = lengths.cuda()
                # Calculate output
                if nn_type == "LSTM":
                    output = model(batch,lengths)
                else:
                    output = model(batch)
                    
                # Calculate MSE losses
                output_valence = output[:,0]
                output_energy = output[:,1]
                output_danceability = output[:,2]
            
                # Calculate MSE losses
                loss_valence = loss_fn(np.squeeze(output_valence), labels[:,0])
                loss_energy = loss_fn(np.squeeze(output_energy), labels[:,1])
                loss_danceability = loss_fn(np.squeeze(output_danceability), labels[:,2])
            
                loss = loss_valence + loss_energy + loss_danceability
                valid_loss += loss.item()
        valid_loss /= len(validation_loader)

        # Check for use of earlyStopping
        if earlyStopping:
            if valid_loss < min_val_loss: # improvement
                torch.save(model.state_dict(),"best.pt")
                epochs_no_improve = 0
                min_val_loss = valid_loss
            else: # no improvement
                epochs_no_improve +=1 
            if epochs_no_improve == patience:
                early_stop = True

        print("Epoch: {}/{}".format(epoch+1,num_epochs), "...", "\033[1mTraining loss: {:.6f}\033[0m".format(train_loss), "...", "\033[1mValidation loss: {:.6f}\033[0m".format(valid_loss))

        # Check early stopping condition
        if early_stop and earlyStopping:
            print('Early stopping!')
            print('Stopped')
            break

    return

# %%
from scipy.stats import spearmanr

def find_multitask_spearman_correlation(model, data_loader,nn_type="LSTM"):
    model.load_state_dict(torch.load("best.pt"))
    model.eval()
    correct = 0
    n_samples = 0
    targets_valence, targets_energy, targets_danceability, predictions_valence, predictions_energy, predictions_danceability = [],[],[],[],[],[]
    with torch.no_grad():
            for batch, labels, lengths in data_loader:
                if torch.cuda.is_available():
                        batch = batch.cuda()
                        labels = labels.cuda()
                        lengths = lengths.cuda()
                if nn_type == "LSTM":
                    output = model(batch,lengths)
                else:
                    output = model(batch)

                
                predictions_valence.extend(output[:,0].cpu().numpy())
                predictions_energy.extend(output[:,1].cpu().numpy())
                predictions_danceability.extend(output[:,2].cpu().numpy())
                
                targets_valence.extend(labels[:,0].cpu().numpy())
                targets_energy.extend(labels[:,1].cpu().numpy())
                targets_danceability.extend(labels[:,2].cpu().numpy())
    
    spearman_correlation_valence = spearmanr(predictions_valence,targets_valence).correlation                               # Find Spearman Correlation for valence
    spearman_correlation_energy = spearmanr(predictions_energy,targets_energy).correlation                                  # Find Spearman Correlation for energy
    spearman_correlation_danceability = spearmanr(predictions_danceability,targets_danceability).correlation                # Find Spearman Correlation for danceability
    
    print("Spearman correlation for \033[1m Valence \033[0m is \033[1m{}\033[0m".format(np.round(spearman_correlation_valence,3)))
    print("Spearman correlation for \033[1m Energy \033[0m is \033[1m{}\033[0m".format(np.round(spearman_correlation_energy,3)))
    print("Spearman correlation for \033[1m Danceability \033[0m is \033[1m{}\033[0m".format(np.round(spearman_correlation_danceability,3)))

    return ((abs(spearman_correlation_valence)+abs(spearman_correlation_energy)+abs(spearman_correlation_danceability))/3)    # Return Mean Spearman Correlation

# %%
# Create ConvNet
in_channels = 1     # number of channels
out_channels = 40   # hidden layer dimension
in_features = 7680  # number of features
output_dim = 3      # output dimension

# Number of epochs
num_epochs = 100

# Define model
model = ConvNet(in_channels, out_channels, in_features, output_dim).double()

if torch.cuda.is_available():
    model = model.cuda()

# Fit
multitask_fit(model, train_loader_multitask_all, val_loader_multitask_all, num_epochs, L2 = 0, earlyStopping=True, nn_type="CNN")
# Out:
# Epoch: 1/100 ... Training loss: 2.806845 ... Validation loss: 0.210929
# Epoch: 2/100 ... Training loss: 0.211133 ... Validation loss: 0.118493
# Epoch: 3/100 ... Training loss: 0.128090 ... Validation loss: 0.113215
# Epoch: 4/100 ... Training loss: 0.105533 ... Validation loss: 0.111959
# Epoch: 5/100 ... Training loss: 0.106875 ... Validation loss: 0.104042
# Epoch: 6/100 ... Training loss: 0.099606 ... Validation loss: 0.100397
# Epoch: 7/100 ... Training loss: 0.092141 ... Validation loss: 0.103455
# Epoch: 8/100 ... Training loss: 0.085407 ... Validation loss: 0.106211
# Epoch: 9/100 ... Training loss: 0.088445 ... Validation loss: 0.155129
# Epoch: 10/100 ... Training loss: 0.083578 ... Validation loss: 0.108988
# Epoch: 11/100 ... Training loss: 0.069783 ... Validation loss: 0.099048
# Epoch: 12/100 ... Training loss: 0.070281 ... Validation loss: 0.094591
# Epoch: 13/100 ... Training loss: 0.066771 ... Validation loss: 0.116001
# Epoch: 14/100 ... Training loss: 0.064228 ... Validation loss: 0.101284
# Epoch: 15/100 ... Training loss: 0.054390 ... Validation loss: 0.091574
# Epoch: 16/100 ... Training loss: 0.054052 ... Validation loss: 0.109418
# Epoch: 17/100 ... Training loss: 0.053157 ... Validation loss: 0.104885
# Epoch: 18/100 ... Training loss: 0.050647 ... Validation loss: 0.115148
# Epoch: 19/100 ... Training loss: 0.056440 ... Validation loss: 0.087613
# Epoch: 20/100 ... Training loss: 0.060258 ... Validation loss: 0.115489
# Epoch: 21/100 ... Training loss: 0.045652 ... Validation loss: 0.101356
# Epoch: 22/100 ... Training loss: 0.043966 ... Validation loss: 0.112654
# Epoch: 23/100 ... Training loss: 0.043429 ... Validation loss: 0.097588
# Epoch: 24/100 ... Training loss: 0.033101 ... Validation loss: 0.119432
# Epoch: 25/100 ... Training loss: 0.033529 ... Validation loss: 0.126589
# Epoch: 26/100 ... Training loss: 0.025298 ... Validation loss: 0.096941
# Epoch: 27/100 ... Training loss: 0.029007 ... Validation loss: 0.104007
# Epoch: 28/100 ... Training loss: 0.025176 ... Validation loss: 0.097820
# Epoch: 29/100 ... Training loss: 0.020172 ... Validation loss: 0.099283
# Early stopping!
# Stopped

# %%
val_spearman_correlation = find_multitask_spearman_correlation(model, val_loader_multitask_all, nn_type="CNN")                # Find Spearman Correlation for validation data
print("Mean spearman correlation of the best model on \033[1mvalidation data\033[0m is \033[1m{}\033[0m\n".format(np.round(val_spearman_correlation,3)))

test_spearman_correlation = find_multitask_spearman_correlation(model, test_loader_multitask_all, nn_type="CNN")              # Find Spearman Correlation for test data
print("Mean spearman correlation of the best model on \033[1mtest data\033[0m is \033[1m{}\033[0m".format(np.round(test_spearman_correlation,3)))
# Out:
# Spearman correlation for  Valence  is 0.579
# Spearman correlation for  Energy  is 0.778
# Spearman correlation for  Danceability  is 0.606
# Mean spearman correlation of the best model on validation data is 0.654
#
# Spearman correlation for  Valence  is 0.61
# Spearman correlation for  Energy  is 0.804
# Spearman correlation for  Danceability  is 0.543
# Mean spearman correlation of the best model on test data is 0.652
